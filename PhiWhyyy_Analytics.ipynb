# %% [markdown]
# <a href="https://colab.research.google.com/github/PhiWhyyy/Analyzing-market-trends/blob/main/PhiWhyyy_Analytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv
with open('/content/phiwhyyy-subscriber-stats.csv', 'r') as f:
  reader = csv.reader(f)
  for row in reader:
    print(row)
# Out:
# ['period_start', 'period_end', 'followers_gained', 'followers_lost', 'followers_net', 'followers_total', 'subscribers_gained', 'subscribers_lost', 'subscribers_net', 'subscribers_total', 'referred_members_gained', 'referred_members_lost', 'referred_members_net', 'referred_members_total', 'referred_member_earnings']
# ['2024-06-01', '2024-06-30', '0', '0', '0', '177', '0', '0', '0', '11', '0', '0', '0', '0', '$0.00']
# ['2024-05-01', '2024-05-31', '1', '0', '1', '177', '0', '0', '0', '11', '0', '0', '0', '0', '$0.00']
# ['2024-04-01', '2024-04-30', '3', '0', '3', '176', '0', '0', '0', '11', '0', '0', '0', '0', '$0.00']
# ['2024-03-01', '2024-03-31', '4', '0', '4', '173', '0', '0', '0', '11', '0', '0', '0', '0', '$0.00']
# ['2024-02-01', '2024-02-29', '2', '0', '2', '169', '0', '0', '0', '11', '0', '0', '0', '0', '$0.00']
# ['2024-01-01', '2024-01-31', '6', '0', '6', '167', '1', '0', '1', '11', '0', '0', '0', '0', '$0.00']
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path ="/content/phiwhyyy-subscriber-stats.csv"
df = pd.read_csv(path)
df.drop(columns=["Unnamed: 0"], inplace=True, errors='ignore')
df.head(7828)
# Out:
#    period_start  period_end  followers_gained  followers_lost  followers_net  \
# 0    2024-06-01  2024-06-30                 0               0              0
# 1    2024-05-01  2024-05-31                 1               0              1
# 2    2024-04-01  2024-04-30                 3               0              3
# 3    2024-03-01  2024-03-31                 4               0              4
# 4    2024-02-01  2024-02-29                 2               0              2
# 5    2024-01-01  2024-01-31                 6               0              6
# 6    2023-12-01  2023-12-31                 0               1             -1
# 7    2023-11-01  2023-11-30                 1               0              1
# 8    2023-10-01  2023-10-31                 8               0              8
# 9    2023-09-01  2023-09-30                 4               0              4
# 10   2023-08-01  2023-08-31                 8               0              8
# ...

# %%
mean_total = df['followers_gained'].mean()
print("Mean of all Followers gained:", mean_total)
# Out:
# Mean of all Followers gained: 4.972972972972973

# %%
mode_total = df['followers_gained'].mode()
print("Mode of all Followers gained:", mode_total)
# Out:
# Mode of all Followers gained: 0    1
# 1    2
# 2    4
# Name: followers_gained, dtype: int64

# %%
# %ls
# Out:
# phiwhyyy-subscriber-stats.csv  sample_data/

# %% [markdown]
# <a href="https://colab.research.google.com/github/PhiWhyyy/Analyzing-market-trends/blob/main/Analyzing_Market_Trends_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv
with open('/content/sample_sales_data.csv', 'r') as f:
  reader = csv.reader(f)
  for row in reader:
    print(row)
# Out:
# Streaming output truncated to the last 5000 lines.
# ['2829', 'c80a1acd-23bc-4707-84af-4952ccf64448', '2022-03-03 09:48:58', 'ae7c026a-2854-4342-8e0b-b1186cedbbe3', 'canned foods', 'non-member', '8.99', '2', '17.98', 'credit card']
# ['2830', '720677ea-fb01-4249-a431-bd0b21d2690b', '2022-03-07 19:44:02', 'ae7c026a-2854-4342-8e0b-b1186cedbbe3', 'canned foods', 'non-member', '8.99', '3', '26.97', 'debit card']
# ['2831', '776f8650-7aea-49f7-ad83-65ab57cf1058', '2022-03-07 12:32:53', 'c4355226-5f80-40ab-b3aa-de4344834a5d', 'canned foods', 'basic', '2.49', '4', '9.96', 'debit card']
# ['2832', '98905194-bdf0-4e0a-9d21-57459885a9ae', '2022-03-06 19:22:20', '7cb00b7d-207a-4179-8f47-297f7f15c555', 'canned foods', 'non-member', '8.99', '4', '35.96', 'cash']
# ['2833', '4dcf0a5b-3a19-4794-8fb5-c35ec61b2f85', '2022-03-01 16:39:50', '049b2171-0eeb-4a3e-bf98-0c290c7821da', 'canned foods', 'basic', '2.49', '4', '9.96', 'e-wallet']
# ...

# %%
pip install pandas

# %%
import pandas as pd

# %%
path ="/content/sample_sales_data.csv"
df = pd.read_csv(path)
df.drop(columns=["Unnamed: 0"], inplace=True, errors='ignore')
df.head(7828)
# Out:
#                             transaction_id            timestamp  \
# 0     a1c82654-c52c-45b3-8ce8-4c2a1efe63ed  2022-03-02 09:51:38
# 1     931ad550-09e8-4da6-beaa-8c9d17be9c60  2022-03-06 10:33:59
# 2     ae133534-6f61-4cd6-b6b8-d1c1d8d90aea  2022-03-04 17:20:21
# 3     157cebd9-aaf0-475d-8a11-7c8e0f5b76e4  2022-03-02 17:23:58
# 4     a81a6cd3-5e0c-44a2-826c-aea43e46c514  2022-03-05 14:32:43
# ...                                    ...                  ...
# 7823  60524862-cd12-47e8-aaa6-9a15e3f2c74d  2022-03-07 12:44:43
# 7824  6c19b9fc-f86d-4526-9dfe-d8027a4d13ee  2022-03-03 18:22:09
# 7825  1c69824b-e399-4b79-a5e7-04a3a7db0681  2022-03-04 19:14:46
# 7826  79aee7d6-1405-4345-9a15-92541e9e1e74  2022-03-03 14:00:09
# 7827  e5cc4f88-e5b7-4ad5-bc1b-12a828a14f55  2022-03-04 15:11:38
#
#                                 product_id           category customer_type  \
# 0     3bc6c1ea-0198-46de-9ffd-514ae3338713              fruit          gold
# ...

# %%
# prompt: how to find the mean of total amount payable

mean_total = df['total'].mean()
print("Mean of total:", mean_total)
# Out:
# Mean of total: 19.70990547962703

# %%
median_total = df["total"].mean()
print("Median of total:",median_total)
# Out:
# Median of total: 19.70990547962703

# %%
unique_payment_type =df["payment_type"].unique()
print("Different types of payment_type used:",unique_payment_type)
# Out:
# Different types of payment_type used: ['e-wallet' 'debit card' 'cash' 'credit card']

# %%
num_unique_payment_type =df["payment_type"].nunique()
print("Different number of types of payment_type used:",num_unique_payment_type)
# Out:
# Different number of types of payment_type used: 4

# %%
unique_customer_type =df["customer_type"].unique()
print("Different types of customer_type used:",unique_customer_type)
# Out:
# Different types of customer_type used: ['gold' 'standard' 'premium' 'basic' 'non-member']

# %%
# !pip install seaborn
import seaborn as sns

# %%
median_unit_price = df["unit_price"].median
print("Median unit price",median_unit_price)
sns.histplot(x="unit_price", data=df)
# Out:
# Median unit price <bound method NDFrame._add_numeric_operations.<locals>.median of 0        3.99
# 1        3.99
# 2        0.19
# 3        0.19
# 4        4.49
#         ...
# 7824    14.19
# 7825    16.99
# 7826    14.19
# 7827    16.99
# 7828    14.99
# Name: unit_price, Length: 7829, dtype: float64>
# <Axes: xlabel='unit_price', ylabel='Count'>

# %%
median_unit_price = df["unit_price"].median
print("Median unit price",median_unit_price)
sns.pairplot(df, x_vars=["unit_price"])
# Out:
# Median unit price <bound method NDFrame._add_numeric_operations.<locals>.median of 0        3.99
# 1        3.99
# 2        0.19
# 3        0.19
# 4        4.49
#         ...
# 7824    14.19
# 7825    16.99
# 7826    14.19
# 7827    16.99
# 7828    14.99
# Name: unit_price, Length: 7829, dtype: float64>

# %%
num_unique_customer_type =df["customer_type"].nunique()
print("Different number of types of customer_type used:",num_unique_customer_type)
# Out:
# Different number of types of customer_type used: 5

# %%
# !pip install seaborn
import seaborn as sns

# %%
# !pip install matplotlib
import matplotlib.pyplot as plt

# %%
def plot_continuous_distribution(data: pd.DataFrame = None, column: str = None, height: int = 8):
  _ = sns.displot(data, x=column, kde=True, height=height, aspect=height/5).set(title=f'Distribution of {column}');

# %%
# prompt: plot the graph for unique payment_type

import seaborn as sns

sns.countplot(x="payment_type", data=df)
# Out:
# <Axes: xlabel='payment_type', ylabel='count'>

# %%
def get_unique_values(data, column):
  num_unique_values = len(data[column].unique())
  value_counts = data[column].value_counts()
  print(f"Column: {column} has {num_unique_values} unique values\n")
  print(value_counts)

# %%
def plot_continuous_distribution(data: pd.DataFrame = None,  column: str = None, row: str = None, height: int = 8):
  _ = sns.displot(data, x=column, y=row, kde=True, height=height, aspect=height/5).set(title=f'Distribution of {column}');

sns.countplot(x="payment_type", data=df)
sns.countplot(y="customer_type",data=df)

def get_unique_values(data, column):
  num_unique_values = len(data[column].unique())
  value_counts = data[column].value_counts()
  print(f"Column: {column} has {num_unique_values} unique values\n")
  print(value_counts)

def plot_categorical_distribution(data: pd.DataFrame = None, column: str = None, height: int = 8, aspect: int = 2):
  _ = sns.catplot(data=data, x=column, kind='count', height=height, aspect=aspect).set(title=f'Distribution of {column}');

def correlation_plot(data: pd.DataFrame = None):
  corr = df.corr()
  corr.style.background_gradient(cmap='red')
  sns.plot(data,x=column,kde=True)

# %%
sns.countplot(x="customer_type",data=df)
# Out:
# <Axes: xlabel='customer_type', ylabel='count'>

# %%
mode_unit_price = df["unit_price"].mode
print("Most frequently bought products cost:",mode_unit_price)
# Out:
# Most frequently bought products cost: <bound method Series.mode of 0        3.99
# 1        3.99
# 2        0.19
# 3        0.19
# 4        4.49
#         ...
# 7824    14.19
# 7825    16.99
# 7826    14.19
# 7827    16.99
# 7828    14.99
# Name: unit_price, Length: 7829, dtype: float64>

# %%
sns.histplot(x="unit_price", data=df)
# Out:
# <Axes: xlabel='unit_price', ylabel='Count'>

# %%
num_mode_quantity = df["quantity"].mode
print("The number of products people most frequently buy together:",num_mode_quantity)
sns.countplot(x="quantity", data=df)
# Out:
# The number of products people most frequently buy together: <bound method Series.mode of 0       2
# 1       1
# 2       2
# 3       4
# 4       2
#        ..
# 7824    2
# 7825    1
# 7826    2
# 7827    4
# 7828    4
# Name: quantity, Length: 7829, dtype: int64>
# <Axes: xlabel='quantity', ylabel='count'>
